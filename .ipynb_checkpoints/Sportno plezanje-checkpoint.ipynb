# %% [markdown]
# # Športno plezanje

# %% [markdown]
# Tu bom naredil projekt pri predmetu Programiranje 1.

# %% [markdown]
# ## Priprava

# %% [markdown]
# Na začetku naložimo paket pandas za delo s podatki. V preambuli je še nekaj vrstic za lepše in lažje delo. Če CSV datoteke še ne obstajajo, jih najprej ustvarimo s pomočjo skripte pripravi_podatke.py.

# %%
import pandas as pd

pd.options.display.max_rows = 30
pd.options.display.max_columns = 16

rezultati = pd.read_csv('C:/Users/Uporabnik/Desktop/projekt/podatki.csv')

# %%
rezultati
# Out:
#      leto        kategorija  stevilo tekmovalcev  1. mesto  2. mesto  \
# 0    2016         cicibanke                   22       328       311
# 1    2016          cicibani                   19       380       333
# 2    2016    mlajse deklice                   31       330       325
# 3    2016      mlajsi decki                   18       360       360
# 4    2016  starejse deklice                   20       400       313
# 5    2016    starejsi decki                   21       335       307
# 6    2016         kadetinje                   12       400       310
# 7    2016            kadeti                   11       345       315
# 8    2016          mladinke                    8       260       231
# 9    2016          mladinci                    9       280       247
# 10   2016           clanice                   20       300       240
# 11   2016             clani                   26       300       240
# 12   2015         cicibanke                   23       390       294
# ...

# %%
rezultati[rezultati["kategorija"] == "clani"]
# Out:
#      leto kategorija  stevilo tekmovalcev  1. mesto  2. mesto  zadnje mesto  \
# 11   2016      clani                   26       300       240            15
# 23   2015      clani                   36       293       260             2
# 35   2014      clani                   39       280       220             5
# 47   2013      clani                   38       300       245             1
# 59   2012      clani                   37       265       225             1
# 71   2011      clani                   34       296       277            10
# 83   2010      clani                   33       231       230            18
# 95   2009      clani                   38       300       225             5
# 107  2008      clani                   41       300       225             5
# 119  2007      clani                   28       280       280            14
# 131  2006      clani                   29       300       231             9
# ...
